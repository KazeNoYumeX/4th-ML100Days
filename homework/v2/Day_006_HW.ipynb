# %% [markdown]
# # EDA：資料分布介紹及繪圖
#
# ## 作業程式碼
# - 本作業將請學員完成以下要求
#     - 請從 Kaggle 平台找尋有興趣的資料集，建議資料筆數超過 10000 筆以上，且需為表格資料
#     - 參考範例程式碼，使用 Matplotlib 繪製許多長條圖、散佈圖、盒鬚圖、折線圖等，並搭配圖表標題、X軸與Y軸標題

# %% [markdown]
# ### 匯入所需套件

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 輸入資料

# %%
import os

# 輸入資料
folder = './data/'
path = os.path.join(folder, 'all_video_games.csv')

raw_data = pd.read_csv(path)

data = raw_data.copy()
data = data.dropna()
data.head()
# Out:
#                                Title Release Date                Developer  \
# 3                           Gothic 3   11/14/2006            Piranha Bytes
# 5   Guitar Hero III: Legends of Rock   10/28/2007  Neversoft Entertainment
# 7                           Xenoraid    11/8/2016                   10tons
# 8             The Sims: Livin' Large    8/27/2000                    Maxis
# 12    Warhammer 40,000: Space Marine     9/6/2011      Relic Entertainment
#
#     Publisher                 Genres                 Genres Splitted  \
# 3       Aspyr            Western RPG              ['Western', 'RPG']
# 5   RedOctane                 Rhythm                      ['Rhythm']
# 7      10tons  Vertical Shoot-'Em-Up    ['Vertical', "Shoot-'Em-Up"]
# 8    EA Games           Virtual Life             ['Virtual', 'Life']
# 12        THQ   Third Person Shooter  ['Third', 'Person', 'Shooter']
#
#                   Product Rating  User Score  User Ratings Count  \
# 3               Rated T For Teen         7.5               832.0
# 5               Rated T For Teen         8.4               144.0
# 7   Rated E +10 For Everyone +10         6.2                 6.0
# 8               Rated T For Teen         7.7                20.0
# 12            Rated M For Mature         7.8               259.0
#
#                                        Platforms Info
# 3   [{'Platform': 'PC', 'Platform Metascore': '63'...
# 5   [{'Platform': 'Wii', 'Platform Metascore': '86...
# 7   [{'Platform': 'PlayStation 4', 'Platform Metas...
# 8   [{'Platform': 'PC', 'Platform Metascore': '82'...
# 12  [{'Platform': 'PC', 'Platform Metascore': '74'...

# %%
data['Release Date'] = pd.to_datetime(data['Release Date'], format='%m/%d/%Y')
data['Release Year'] = data['Release Date'].dt.year
data.head()
# Out:
#                                Title Release Date                Developer  \
# 3                           Gothic 3   2006-11-14            Piranha Bytes
# 5   Guitar Hero III: Legends of Rock   2007-10-28  Neversoft Entertainment
# 7                           Xenoraid   2016-11-08                   10tons
# 8             The Sims: Livin' Large   2000-08-27                    Maxis
# 12    Warhammer 40,000: Space Marine   2011-09-06      Relic Entertainment
#
#     Publisher                 Genres                 Genres Splitted  \
# 3       Aspyr            Western RPG              ['Western', 'RPG']
# 5   RedOctane                 Rhythm                      ['Rhythm']
# 7      10tons  Vertical Shoot-'Em-Up    ['Vertical', "Shoot-'Em-Up"]
# 8    EA Games           Virtual Life             ['Virtual', 'Life']
# 12        THQ   Third Person Shooter  ['Third', 'Person', 'Shooter']
#
#                   Product Rating  User Score  User Ratings Count  \
# 3               Rated T For Teen         7.5               832.0
# 5               Rated T For Teen         8.4               144.0
# 7   Rated E +10 For Everyone +10         6.2                 6.0
# 8               Rated T For Teen         7.7                20.0
# 12            Rated M For Mature         7.8               259.0
#
#                                        Platforms Info  Release Year
# 3   [{'Platform': 'PC', 'Platform Metascore': '63'...          2006
# 5   [{'Platform': 'Wii', 'Platform Metascore': '86...          2007
# 7   [{'Platform': 'PlayStation 4', 'Platform Metas...          2016
# 8   [{'Platform': 'PC', 'Platform Metascore': '82'...          2000
# 12  [{'Platform': 'PC', 'Platform Metascore': '74'...          2011

# %% [markdown]
# ### 繪製長條圖

# %%
release_data = data['Release Year'].value_counts().sort_index()

plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei']
plt.bar(x=release_data.index,
        height=release_data.values)
plt.title('Games Released Over the Years')
plt.show()

# %% [markdown]
# ### 繪製盒鬚圖

# %% [markdown]
# ### 繪製散佈圖

# %%
plt.scatter(data.index, data['User Score'])
plt.title('User Score Scatter Plot')
plt.xlabel('Index')
plt.ylabel('User Score')
plt.show()

# %% [markdown]
# ### 繪製折線圖

# %%
# Sort by year
plt.plot(release_data.index, release_data.values)
plt.title('Games Released Over the Years')
plt.xlabel('Year')
plt.ylabel('Number of Games')
plt.show()

# %%
plt.boxplot(data['Release Year'])
plt.title('Release Year Box Plot')
plt.xlabel('Release Year')
plt.show()
