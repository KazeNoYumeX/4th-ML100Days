# %% [markdown]
# ## 練習時間
#
# 相信大家對回歸問題及分類問題都有初步的了解。今天的作業希望大家搜尋有關 multi-label 的案例問題。下圖是電影 "奇異博士" 的分類。可以看到同時有 "Action", "Adventure", "Fantasy" 的類別存在，代表這是個多標籤的問題。

# %% [markdown]
# ![image](data:image/png;base64,...)

# %% [markdown]
# ## 請搜尋目標為多標籤問題 (Multi-label) 的機器學習案例，了解其資料來源、目標以及評估指標為何
#
# ## Hint: 服飾
#
# ##### Ans:
#
# - [多標籤評論分類](https://www.kaggle.com/code/rhodiumbeng/classifying-multi-label-comments-0-9741-lb)
# - 資料來源: [Toxic Comment Classification Challenge](https://www.kaggle.com/competitions/jigsaw-toxic-comment-classification-challenge)
# - 目標: 立一個模型來分類評論是否包含不同類型的惡意行為，包括 toxic, severe_toxic, obscene, threat, insult, identity_hate
# - 評估指標: 使用準確度 (Accuracy) 來評估模型的預測結果
